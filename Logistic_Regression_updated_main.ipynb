# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipika591/Basic_Python/blob/main/Logistic_Regression_updated_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import train_test_split # train and test
from sklearn import metrics
#from sklearn import preprocessing
from sklearn.metrics import classification_report

# %%
# loading claimants data
claimants = pd.read_csv("claimants.csv")
claimants
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
claimants.head(10)
claimants.isnull().sum()
# Out:
# CASENUM       0
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
claimants.describe()
# Out:
#             CASENUM     ATTORNEY       CLMSEX     CLMINSUR     SEATBELT  \
# count   1340.000000  1340.000000  1328.000000  1299.000000  1292.000000
# mean   11202.001493     0.488806     0.558735     0.907621     0.017028
# std     9512.750796     0.500061     0.496725     0.289671     0.129425
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     4177.000000     0.000000     0.000000     1.000000     0.000000
# 50%     8756.500000     0.000000     1.000000     1.000000     0.000000
# 75%    15702.500000     1.000000     1.000000     1.000000     0.000000
# max    34153.000000     1.000000     1.000000     1.000000     1.000000
#
#             CLMAGE         LOSS
# count  1151.000000  1340.000000
# mean     28.414422     3.806307
# std      20.304451    10.636903
# min       0.000000     0.000000
# 25%       9.000000     0.400000
# 50%      30.000000     1.069500
# 75%      43.000000     3.781500
# max      95.000000   173.604000

# %%
sb.boxplot(x="ATTORNEY",y="CLMAGE",data=claimants,palette="hls")
# Out:
# <ipython-input-6-0fb21a21b46f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x="ATTORNEY",y="CLMAGE",data=claimants,palette="hls")
# <Axes: xlabel='ATTORNEY', ylabel='CLMAGE'>

# %%
# Droping first column
claimants.drop(["CASENUM"],inplace=True,axis = 1)
#cat_cols = ["ATTORNEY","CLMSEX","SEATBELT","CLMINSUR"]
#cont_cols = ["CLMAGE","LOSS"]

# Getting the barplot for the categorical columns

# %%
claimants
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1335         1     0.0       1.0       0.0     NaN   0.576
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 6 columns]

# %%
sb.countplot(x="ATTORNEY",data=claimants,palette="hls")
# Out:
# <ipython-input-9-11783a909758>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="ATTORNEY",data=claimants,palette="hls")
# <Axes: xlabel='ATTORNEY', ylabel='count'>

# %%
pd.crosstab(claimants.ATTORNEY,claimants.CLMINSUR)
# Out:
# CLMINSUR  0.0  1.0
# ATTORNEY
# 0          76  585
# 1          44  594

# %%
pd.crosstab(claimants.ATTORNEY,claimants.CLMINSUR).plot(kind = 'bar')
# Out:
# <Axes: xlabel='ATTORNEY'>

# %%
sb.countplot(x="SEATBELT",data=claimants,palette="hls")
# Out:
# <ipython-input-12-736aa54ca8ba>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="SEATBELT",data=claimants,palette="hls")
# <Axes: xlabel='SEATBELT', ylabel='count'>

# %%
sb.countplot(x="CLMINSUR",data=claimants,palette="hls")
# Out:
# <ipython-input-13-df0f504b3d7d>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="CLMINSUR",data=claimants,palette="hls")
# <Axes: xlabel='CLMINSUR', ylabel='count'>

# %%
pd.crosstab(claimants.SEATBELT,claimants.CLMINSUR).plot(kind="bar")
# Out:
# <Axes: xlabel='SEATBELT'>

# %%
sb.countplot(x="CLMSEX",data=claimants,palette="hls")
# Out:
# <ipython-input-15-2ceb9cb403b0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x="CLMSEX",data=claimants,palette="hls")
# <Axes: xlabel='CLMSEX', ylabel='count'>

# %%
pd.crosstab(claimants.CLMSEX,claimants.CLMINSUR).plot(kind="bar")
# Out:
# <Axes: xlabel='CLMSEX'>

# %%
claimants.isnull().sum()
#claimants.shape # 1340 6 => Before dropping null values
# To drop null values ( dropping rows)
#claimants.dropna().shape # 1096 6 => After dropping null values
# Out:
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
# Fill nan values with mode of the categorical column
claimants["CLMSEX"].fillna(1,inplace=True) # claimants.CLMSEX.mode() = 1
claimants["CLMINSUR"].fillna(1,inplace=True) # claimants.CLMINSUR.mode() = 1
claimants["SEATBELT"].fillna(0,inplace=True) # claimants.SEATBELT.mode() = 0
# Out:
# <ipython-input-18-721ad555ceec>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   claimants["CLMSEX"].fillna(1,inplace=True) # claimants.CLMSEX.mode() = 1
# <ipython-input-18-721ad555ceec>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   claimants["CLMINSUR"].fillna(1,inplace=True) # claimants.CLMINSUR.mode() = 1
# <ipython-input-18-721ad555ceec>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   claimants["SEATBELT"].fillna(0,inplace=True) # claimants.SEATBELT.mode() = 0

# %%
claimants.CLMSEX.mode()
claimants.CLMINSUR.mode()
claimants.SEATBELT.mode()
claimants.CLMAGE.mean()
# Out:
# 28.414422241529106

# %%
claimants.CLMAGE.fillna(28.4144,inplace=True) # claimants.CLMAGE.mean() = 28.4
# Out:
# <ipython-input-20-c2f68c9028fe>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   claimants.CLMAGE.fillna(28.4144,inplace=True) # claimants.CLMAGE.mean() = 28.4

# %%
claimants.isnull().sum()
# Out:
# ATTORNEY    0
# CLMSEX      0
# CLMINSUR    0
# SEATBELT    0
# CLMAGE      0
# LOSS        0
# dtype: int64

# %%
# Model building
from sklearn.linear_model import LogisticRegression
claimants.shape
# Out:
# (1340, 6)

# %%
X = claimants.iloc[:,[1,2,3,4,5]]
Y = claimants.iloc[:,0]
classifier = LogisticRegression()
classifier.fit(X,Y)
# Out:
# LogisticRegression()

# %%
classifier.coef_  # coefficients of features
# Out:
# array([[ 0.31687491,  0.5055026 , -0.52613497,  0.00660526, -0.32241077]])

# %%
classifier.predict_proba (X) # Probability values
# Out:
# array([[9.99974053e-01, 2.59465658e-05],
#        [4.95419392e-01, 5.04580608e-01],
#        [4.25079704e-01, 5.74920296e-01],
#        ...,
#        [2.85388975e-01, 7.14611025e-01],
#        [6.86705235e-01, 3.13294765e-01],
#        [3.38824277e-01, 6.61175723e-01]])

# %%
y_pred = classifier.predict(X)
claimants["y_pred"] = y_pred
claimants
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT   CLMAGE    LOSS  y_pred
# 0            0     0.0       1.0       0.0  50.0000  34.940       0
# 1            1     1.0       0.0       0.0  18.0000   0.891       1
# 2            1     0.0       1.0       0.0   5.0000   0.330       1
# 3            0     0.0       1.0       1.0  31.0000   0.037       1
# 4            1     0.0       1.0       0.0  30.0000   0.038       1
# ...        ...     ...       ...       ...      ...     ...     ...
# 1335         1     0.0       1.0       0.0  28.4144   0.576       1
# 1336         0     1.0       1.0       0.0  46.0000   3.705       0
# 1337         1     1.0       1.0       0.0  39.0000   0.099       1
# 1338         0     1.0       0.0       0.0   8.0000   3.177       0
# 1339         1     1.0       1.0       0.0  30.0000   0.688       1
#
# [1340 rows x 7 columns]

# %%
y_prob = pd.DataFrame(classifier.predict_proba(X.iloc[:,:]))
new_df = pd.concat([claimants,y_prob],axis=1)
new_df
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT   CLMAGE    LOSS  y_pred         0  \
# 0            0     0.0       1.0       0.0  50.0000  34.940       0  0.999974
# 1            1     1.0       0.0       0.0  18.0000   0.891       1  0.495419
# 2            1     0.0       1.0       0.0   5.0000   0.330       1  0.425080
# 3            0     0.0       1.0       1.0  31.0000   0.037       1  0.489496
# 4            1     0.0       1.0       0.0  30.0000   0.038       1  0.363263
# ...        ...     ...       ...       ...      ...     ...     ...       ...
# 1335         1     0.0       1.0       0.0  28.4144   0.576       1  0.406778
# 1336         0     1.0       1.0       0.0  46.0000   3.705       0  0.549460
# 1337         1     1.0       1.0       0.0  39.0000   0.099       1  0.285389
# 1338         0     1.0       0.0       0.0   8.0000   3.177       0  0.686705
# 1339         1     1.0       1.0       0.0  30.0000   0.688       1  0.338824
#
#              1
# 0     0.000026
# 1     0.504581
# 2     0.574920
# 3     0.510504
# 4     0.636737
# ...        ...
# 1335  0.593222
# 1336  0.450540
# 1337  0.714611
# 1338  0.313295
# 1339  0.661176
#
# [1340 rows x 9 columns]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y,y_pred)
print (confusion_matrix)
# Out:
# [[435 250]
#  [147 508]]

# %%
pd.crosstab(y_pred,Y)
# Out:
# ATTORNEY    0    1
# row_0
# 0         435  147
# 1         250  508

# %%
#type(y_pred)
accuracy = sum(Y==y_pred)/claimants.shape[0]
accuracy
# Out:
# 0.7037313432835821

# %%
from sklearn.metrics import classification_report
print (classification_report (Y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.64      0.69       685
#            1       0.67      0.78      0.72       655
#
#     accuracy                           0.70      1340
#    macro avg       0.71      0.71      0.70      1340
# weighted avg       0.71      0.70      0.70      1340

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Logit_roc_score=roc_auc_score(Y,classifier.predict(X))
Logit_roc_score
# Out:
# 0.7053045077171672

# %%
fpr, tpr, thresholds = roc_curve(Y,classifier.predict_proba(X)[:,1])
plt.plot(fpr, tpr, label='Logistic Regression (area=%0.2f)'% Logit_roc_score)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
y_prob1 = pd.DataFrame(classifier.predict_proba(X)[:,1])

# %%
y_prob1
# Out:
#              0
# 0     0.000026
# 1     0.504581
# 2     0.574920
# 3     0.510504
# 4     0.636737
# ...        ...
# 1335  0.593222
# 1336  0.450540
# 1337  0.714611
# 1338  0.313295
# 1339  0.661176
#
# [1340 rows x 1 columns]

# %%
import statsmodels.api as sm

# %%
logit = sm.Logit(Y, X)

# %%
logit.fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.609294
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               ATTORNEY   No. Observations:                 1340
# Model:                          Logit   Df Residuals:                     1335
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 20 Nov 2024   Pseudo R-squ.:                  0.1207
# Time:                        11:09:34   Log-Likelihood:                -816.45
# converged:                       True   LL-Null:                       -928.48
# Covariance Type:            nonrobust   LLR p-value:                 2.515e-47
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CLMSEX         0.3005      0.116      2.591      0.010       0.073       0.528
# CLMINSUR       0.4167      0.124      3.364      0.001       0.174       0.660
# SEATBELT      -0.6828      0.522     -1.308      0.191      -1.706       0.341
# CLMAGE         0.0059      0.003      1.951      0.051   -2.58e-05       0.012
# LOSS          -0.3262      0.029    -11.234      0.000      -0.383      -0.269
# ==============================================================================
# """

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00145985, 0.00145985,
#        0.00291971, 0.00291971, 0.00437956, 0.00437956, 0.00583942,
#        0.00583942, 0.00729927, 0.00729927, 0.00875912, 0.00875912,
#        0.01021898, 0.01021898, 0.01167883, 0.01167883, 0.01313869,
#        0.90687023, 0.90687023, 0.90839695, 0.90839695, 0.90992366,
#        0.90992366, 0.91145038, 0.91145038, 0.9129771 , 0.9129771 ,
#        0.91603053, 0.91603053, 0.91908397, 0.91908397, 0.92061069,
#        0.92061069, 0.9221374 , 0.9221374 , 0.92366412, 0.92366412,
#        0.92519084, 0.92519084, 0.92671756, 0.92671756, 0.92824427,
#        0.92824427, 0.92977099, 0.92977099, 0.93129771, 0.93129771,
#        0.93435115, 0.93435115, 0.93587786, 0.93587786, 0.93587786,
#        0.93587786, 0.93740458, 0.93740458, 0.9389313 , 0.9389313 ,
#        0.94045802, 0.94045802, 0.94351145, 0.94351145, 0.94656489,
#        0.94656489, 0.94961832, 0.94961832, 0.95114504, 0.95114504,
#        0.95267176, 0.95267176, 0.95419847, 0.95419847, 0.95572519,
#        0.95572519, 0.95725191, 0.95725191, 0.95877863, 0.95877863,
#        0.96030534, 0.96030534, 0.96183206, 0.96183206, 0.96335878,
#        0.96335878, 0.9648855 , 0.9648855 , 0.96641221, 0.96641221,
#        0.96793893, 0.96793893, 0.97099237, 0.97099237, 0.97251908,
#        0.97251908, 0.9740458 , 0.9740458 , 0.97557252, 0.97557252,
#        0.97709924, 0.97709924, 0.97862595, 0.97862595, 0.97862595,
#        0.97862595, 0.98167939, 0.98167939, 0.98320611, 0.98320611,
#        0.98473282, 0.98473282, 0.98778626, 0.98778626, 0.99083969,
#        0.99083969, 0.99236641, 0.99236641, 0.99389313, 0.99389313,
#        0.99694656, 0.99694656, 0.99847328, 0.99847328, 1.        ,
#        1.        ])

# %%
from sklearn.metrics import accuracy_score
accuracy_ls = []
for thres in thresholds:
    y_pred = np.where(classifier.predict_proba(X)[:,1]>thres,1,0)
    accuracy_ls.append(accuracy_score(Y, y_pred, normalize=True))

accuracy_ls = pd.concat([pd.Series(thresholds), pd.Series(accuracy_ls)],
                        axis=1)
accuracy_ls.columns = ['thresholds', 'accuracy']
accuracy_ls.sort_values(by='accuracy', ascending=False, inplace=True)
accuracy_ls
# Out:
#        thresholds  accuracy
# 321  5.250989e-01  0.713433
# 320  5.285839e-01  0.713433
# 308  5.424822e-01  0.712687
# 310  5.404699e-01  0.712687
# 319  5.293810e-01  0.712687
# ..            ...       ...
# 0             inf  0.511194
# 1    7.689822e-01  0.511194
# 548  1.435155e-11  0.492537
# 549  7.994528e-12  0.491791
# 550  1.331471e-24  0.489552
#
# [551 rows x 2 columns]

# %%
from numpy import argmax
J = tpr - fpr
ix = argmax(J)
best_thresh = thresholds[ix]
print('Best Threshold=%f' % (best_thresh))
# Out:
# Best Threshold=0.525099

# %%
threshold = 0.525080
preds = np.where(classifier.predict_proba(X)[:,1] > threshold, 1, 0)
print(classification_report(Y,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.70       685
#            1       0.69      0.76      0.72       655
#
#     accuracy                           0.71      1340
#    macro avg       0.72      0.72      0.71      1340
# weighted avg       0.72      0.71      0.71      1340
